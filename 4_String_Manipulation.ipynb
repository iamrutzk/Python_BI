# %%
dna_seq="ATCGTGACGAACAAGATAGAC"
dna_seq
print("Original DNA sequence is:",dna_seq)
first_base=dna_seq[0]
print("First base of DNA sequence is:",first_base)

last_base=dna_seq[-1]
print("Last base of DNA sequence is:",last_base)
dna_len=len(dna_seq)
# Out:
# Original DNA sequence is: ATCGTGACGAACAAGATAGAC
# First base of DNA sequence is: A
# Last base of DNA sequence is: C

# %%
print("Original DNA sequence is:",dna_seq)
dna_seq[3:9]

# first five
dna_seq[0:5]

# last five
dna_seq[-5:]

# reverse seq
rev_seq=dna_seq[::-1]
print("Reverse DNA sequence is:",rev_seq)


# Skip every second nucliotide
dna_seq[::-2]
# Out:
# Original DNA sequence is: ATCGTGACGAACAAGATAGAC
# Reverse DNA sequence is: CAGATAGAACAAGCAGTGCTA
# 'CGTGAAGATCA'

# %%
dna_seq[:5]
# Out:
# 'ATCGT'

# %%
 # "ABCD"
    0123
   -4-3-2-1
 #fetching [index]Python-0 based and Two types:positive L --->R ,negative L<------R
 # indexing -specific charcter from string
 # slicing-substring[start:end:step]

# %%
info="Gene expression analysis in tumor cells"
length=len(info)
print("lenght of sentence:",length)
# Out:
# lenght of sentence: 39

# %%
info[::3]
# Out:
# 'Gexei as  m l'

# %%
info
info[0:4]
info[5:15]
# Out:
# 'expression'

# %%
info[0]
# Out:
# 'G'

# %%
print(f"First Nucleotide:{first_base}")
# Out:
# First Nucleotide:A

# %%
print("Original DNA sequence is:",dna_seq)
count_A=dna_seq.count("A")
print("A:",count_A)

count_T=dna_seq.count("T")
print("T:",count_T)

count_G=dna_seq.count("G")
print("G:",count_G)

count_C=dna_seq.count("C")
print("C:",count_C)
# Out:
# Original DNA sequence is: ATCGTGACGAACAAGATAGAC
# A: 9
# T: 3
# G: 5
# C: 4

# %%
print("Original DNA sequence is:",dna_seq)
lower_seq=dna_seq.lower()
lower_seq

upper_seq=lower_seq.upper()
upper_seq

# find for index
index=dna_seq.find("AAC")
index

# replace
Rna_seq=dna_seq.replace("T","U")
print("RNA sequence is:",Rna_seq)
# Out:
# Original DNA sequence is: ATCGTGACGAACAAGATAGAC
# RNA sequence is: AUCGUGACGAACAAGAUAGAC

# %%
fasta_header=">gene1_homo_sapiens_BRCA1_protein"
len(fasta_header)
gene_name=fasta_header.split("_")[3]
gene_name
# Out:
# 'BRCA1'

# %%
species="Human"
length=3200000000
print("The lenght of",species,"DNA is",length)
# Out:
# The lenght of Human DNA is 3200000000

# %%
# format
print("The lenght of {} DNA is {}".format(species,length))
# Out:
# The lenght of Human DNA is 3200000000

# %%
print(f"The lenght of {species} DNA is {length}")
# Out:
# The lenght of Human DNA is 3200000000

# %%
species="Yeast"
GC=38.25564422

# %%
print(f"The GC content of {species } is {GC:.2f} %")
# Out:
# The GC content of Yeast is 38.26 %
