# %%
gene_count = 50  # int
expression_level = 12.5  # float
dna_sequence = "ATGCGT"  # str
is_expressed = True  # bool

# %%
type(gene_count)
isinstance(dna_sequence,int)
is_expressed.__class__
# Out:
# bool

# %%
age=20
age
age=age+10

# %%
age
# Out:
# 30

# %%
name="DrOmics"
name
name=name+"ResearchLabs"

# %%
name
# Out:
# 'DrOmicsResearchLabs'

# %%
## Operators Arithmatic +,-,*,=,/,//,**,%
## Logical AND,OR,NOT(&,|,!)
# Comparative >,<,>=,<=,==,!=
a=10
b=20
c=a+b
c
b-a
a*b
b/a
# Out:
# 2.0

# %%
# division
print(b/a)
print(30/10)
# Out:
# 2.0
# 3.0

# %%
# Floor division
print(b//a)
print(30//10)
# Out:
# 2
# 3

# %%
# Exponentiation **
a=2
b=3
a**b
# Out:
# 8

# %%
# modulus %
a=7
b=3
a%b
# Out:
# 1

# %% [markdown]
# AND T T
# OR T F / FT FF
# Not

# %%
a
b
a>b
10 <5
# Out:
# False

# %%
20>50 and 20<30
# Out:
# False

# %%
20>50 or 20<30
# Out:
# True

# %%
print(100>=100)
# Out:
# True

# %%
100 != 10
# Out:
# True

# %%
num1=100
num2=200

result=num1+num2
result
# Out:
# 300

# %%
#Type casting
num1='100'
num2=200

num1=int(num1)

result=num1+num2
result
# Out:
# 300

# %%
num1=input("Enter First Number:")
num2=input("Enter Second Number:")

#Type casting
A=int(num1)
B=int(num2)
result=A+B
result
# Out:
# Enter First Number:300
# Enter Second Number:700
# 1000

# %%
#int------>float
gene_count=1500
gene_count

gc=float(gene_count)
gc
type(gene_count)
type(gc)
print(gc,type(gc))
# Out:
# 1500.0 <class 'float'>

# %%
gene=1000
type(gene)
gene_str=str(gene)
type(gene_str)
# Out:
# str

# %%
#User  Input
A=int(input("Enter First Number:"))
B=int(input("Enter second Number:"))
result=A+B
result
# Out:
# Enter First Number:10
# Enter second Number:20
# 30
