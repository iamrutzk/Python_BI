# %%
# Python Script  comment
2+3
# Out:
# 5

# %%
print("Welcome to Python programming")
# Out:
# Welcome to Python programming

# %%
# Variable-declarae and call
# Rules
name="NGS"
myvar=10
Name="OMICS"

# %% [markdown]
# 1.start with letter or underscore
# 2.No . and number at start
# 3.case sensitive
# 4.Avoide reserved word/keywords
# 5.Naming Convention
# 6.No special character
# 7.No space in variable name

# %%
_myvar1=100

# %%
name
_myvar1
# Out:
# 100

# %%
lssdc
# Out:
# 123345

# %%
name
Name
# Out:
# 'OMICS'

# %%
'''
if =20
for =200
while =300
'''
name
# Out:
# 'NGS'

# %%
x=100
y=200

# %%
z=x+y
z
height_cm=200

# NAming Convention camel ,snake
totalSale=5000
total_sale=50000

# Special character
price_rs=1000
# price$usd=100  $ is not valid

# %% [markdown]
# *Data Types*
# Numerical -integer,float,complex
# string character
# boolean-true,false

# %%
# Numerical
x=10
y=20.5
z=1+2j

# %%
type(x)
# Out:
# int

# %%
y
type(y)
# Out:
# float

# %%
z
type(z)
# Out:
# complex

# %%
# String
sequence="DNA"
sequence
seq="ATGCAGTAGCAGATGA"
seq
# Out:
# 'ATGCAGTAGCAGATGA'

# %%
type(sequence)
# Out:
# str

# %%
p=10
p
type(p)
# Out:
# int

# %%
p='10'
p
type(p)
# Out:
# str

# %%
# Boolean T/F
is_present=True
is_present
type(is_present)
# Out:
# bool

# %%
is_exp=False
is_exp
type(is_exp)
# Out:
# bool

# %%
isinstance(x,str)
isinstance(p,bool)
# Out:
# False

# %%
x.__class__
# Out:
# int

# %%
print(z)
# Out:
# (1+2j)

# %%
print("Original Variable and Datatypes:")
print("Integer Value:",x)
print("X DataType:",type(x))
# Out:
# Original Variable and Datatypes:
# Integer Value: 100
# X DataType: <class 'int'>
